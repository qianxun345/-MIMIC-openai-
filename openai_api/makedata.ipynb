# %%
from dotenv import load_dotenv
load_dotenv('../openai.env')
# Out:
# True

# %%
from langchain.document_loaders import DirectoryLoader, TextLoader, CSVLoader
loader = CSVLoader('../unzip_data/a.csv')
documents = loader.load()
print(documents[0].page_content)
for i in documents:
    print(i.page_content)
# Out:
# id: 1
# name: John
# age: 20
# id: 1
# name: John
# age: 20
# id: 2
# name: Jack
# age: 30

# %%
from langchain.embeddings import OpenAIEmbeddings
import openai
import os

openai.api_key = os.getenv('OPENAI_API_KEY')
embeddings = OpenAIEmbeddings()
embeddings.embed_documents(documents)
[[0.042400114238262177, 0.03367273509502411,..., -0.002644613850861788, 0.015433389693498611],
 [-0.026171881705522537, 0.010133338160812855,..., -0.06366696208715439, 0.0023932424373924732]]
# Out:
# client=<class 'openai.api_resources.embedding.Embedding'> model='text-embedding-ada-002' deployment='text-embedding-ada-002' openai_api_version='2022-12-01' openai_api_base=None openai_api_type=None embedding_ctx_length=8191 openai_api_key=None openai_organization=None allowed_special=set() disallowed_special='all' chunk_size=1000 max_retries=6

# %%
# 存储向量
from tqdm.auto import tqdm
from langchain.vectorstores import Chroma

persist_directory = '../DCPT_chroma'
batch_size = 64
# for i in tqdm(range(0, len(documents), batch_size)):
#     i_end = min(i+batch_size, len(documents))
#     vectorstore = Chroma.from_documents(documents[i:i_end], embeddings, persist_directory=persist_directory)
#     vectorstore.persist()
vectorstore = Chroma.from_documents(documents, embeddings, persist_directory=persist_directory)
vectorstore.persist()

# %%
db = Chroma(persist_directory=persist_directory, embedding_function=embeddings)
query = "what is the DISCHTIME going to be when his/her ADMITTIME is 2157-10-18 19:34:00 and its DIAGNOSIS is CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS GRAFT /SDA?"
docs = db.similarity_search(query, k=10)
print(len(docs))
print(docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 db = Chroma(persist_directory=persist_directory, embedding_function=embeddings)
#       2 query = "what is the DISCHTIME going to be when his/her ADMITTIME is 2157-10-18 19:34:00 and its DIAGNOSIS is CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS GRAFT /SDA?"
# ----> 3 docs = db.similarity_search(query, k=10)
#       4 print(len(docs))
#       5 print(docs[0].page_content)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\langchain\vectorstores\chroma.py:181, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     164 def similarity_search(
#     165     self,
#     166     query: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> List[Document]:
#     171     """Run similarity search with Chroma.
#     172
#     173     Args:
#    (...)
# ...
